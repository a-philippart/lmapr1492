# %%
from pymatgen.ext.matproj import MPRester
from pymatgen.analysis.diffraction.xrd import XRDCalculator
import matplotlib.pyplot as plt

# %%
with MPRester("MVjrPtjUJ4K2IdZ4zJmL2QqGBqEUCt6C") as m:
    structure = m.get_structure_by_material_id("mp-22660")
# Out:
# Retrieving MaterialsDoc documents:   0%|          | 0/1 [00:00<?, ?it/s]

# %%
Lambda = 1.54060 #un rayonnement X incident Cu Kα de longueur d’onde λ=1.54060 Å.
pattern = XRDCalculator(Lambda).get_pattern(structure)

# %%
def to_print(num):
    print("pic ", num+1, " pour un rayonnement X de longueur d’onde: λ=",Lambda, "Å :")
    print("        Angle 2Θ :", pattern.x[num],"°")
    print("        Intensité du pic :", pattern.y[num])
    print("        Indices hkl :", str(pattern.hkls[num][0]['hkl']))
    #print("        Multiplicité :" ,str(pattern.hkls[num][0]['multiplicity']))
    print("        d :", pattern.d_hkls[num], "\n")

# %% [markdown]
# # Déterminer les 3 premiers pics du diffractogramme

# %%
for i in range(3):
    to_print(i)
# Out:
# pic  1  pour un rayonnement X de longueur d’onde: λ= 1.5406 Å :
#         Angle 2Θ : 14.004610880571882 °
#         Intensité du pic : 3.4429854627092005
#         Indices hkl : (1, 1, 1)
#         d : 6.318632956217304
#
# pic  2  pour un rayonnement X de longueur d’onde: λ= 1.5406 Å :
#         Angle 2Θ : 28.22405031737239 °
#         Intensité du pic : 59.15568731102593
#         Indices hkl : (2, 2, 2)
#         d : 3.159316478108652
#
# pic  3  pour un rayonnement X de longueur d’onde: λ= 1.5406 Å :
#         Angle 2Θ : 31.744610168131665 °
#         Intensité du pic : 0.4856346045593082
#         Indices hkl : (0, 1, 0)
#         d : 2.81651195478864

# %% [markdown]
# # X-Ray Diffraction Patterns

# %%
XRDCalculator(symprec=0.1).get_plot(structure)
# Out:
# <Axes: xlabel='$2\\theta$ ($^\\circ$)', ylabel='Intensities (scaled)'>

# %% [markdown]
# J'obtiens le même Diffraction Patterns que sur Material Project.
